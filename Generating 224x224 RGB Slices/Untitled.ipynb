# %%
import os
import re
import numpy as np
import pandas as pd
import nibabel as nib
from glob import glob
from scipy.ndimage import binary_closing, binary_fill_holes
from skimage.transform import resize
from PIL import Image

# ─── CONFIG ───────────────────────────────────────────────────────────
BASE_IN  = "/Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd"
SITES    = ["KKI","NeuroIMAGE","NYU","OHSU","Peking_1","Peking_2","WashU"]
CSV_MAP  = {s: os.path.join(BASE_IN, s, f"{s}_phenotypic.csv") for s in SITES}

BASE_OUT = os.path.join(BASE_IN, "Slices")
N_TIME   = 50     # number of timepoints to extract (middle frames)
N_SLICE  = 50     # number of slices per axis
OUT_SIZE = (224, 224)
EXPECTED_SLICES = N_TIME * N_SLICE  # 2500 slices per subject

# ─── HELPERS ───────────────────────────────────────────────────────────
def pick_latest_run(files):
    """Select the nifti file with the highest session/run numbers"""
    def key(f):
        m = re.search(r"session_(\d+)_rest_(\d+)", f)
        return (int(m.group(1)), int(m.group(2))) if m else (-1, -1)
    return sorted(files, key=key)[-1] if files else None


def make_brain_mask(vol4d):
    """Create 3D brain mask from 4D fMRI data"""
    mean_vol = vol4d.mean(axis=3)
    m0 = mean_vol > 0
    m1 = binary_closing(m0, iterations=2)
    return binary_fill_holes(m1)


def process_slice(slice_data, out_size):
    """Process individual slice with masking after resizing"""
    resized = resize(slice_data, out_size, preserve_range=True)
    mask = resize((slice_data > 0).astype(float), out_size, order=0, preserve_range=True) > 0.5
    resized[~mask] = 0
    return resized

# ─── MAIN PROCESSING ──────────────────────────────────────────────────
for site in SITES:
    print(f"Processing site: {site}")
    csv_path = CSV_MAP[site]
    if not os.path.exists(csv_path):
        print(f"⚠ CSV not found: {csv_path}")
        continue
        
    df = pd.read_csv(csv_path)
    subj_col = df.columns[0]  # First column contains subject IDs

    for subj in df[subj_col].astype(str):
        # try raw and zero-padded IDs
        raw = str(subj)
        padded = raw.zfill(7)
        if os.path.isdir(os.path.join(BASE_IN, site, raw)):
            subj_dir = raw
        elif os.path.isdir(os.path.join(BASE_IN, site, padded)):
            subj_dir = padded
        else:
            print(f"⚠ Subject dir missing: {site}/{raw} or {site}/{padded}")
            continue
        subj_path = os.path.join(BASE_IN, site, subj_dir)
        output_dir = os.path.join(BASE_OUT, site, subj_dir)

        # Check if subject already has complete set of slices
        if os.path.exists(output_dir):
            existing_files = glob(os.path.join(output_dir, "*.png"))
            if len(existing_files) >= EXPECTED_SLICES:
                print(f"✅ Skipping {site}/{subj_dir} (already has {len(existing_files)} slices)")
                continue

        # Find and select the best run
        runs = glob(os.path.join(subj_path, "*.nii.gz"))
        if not runs:
            print(f"⚠ No NIFTI files for {site}/{subj_dir}")
            continue
        chosen_file = pick_latest_run(runs)
        print(f"Processing: {site}/{subj_dir} with {os.path.basename(chosen_file)}")

        # Load and prepare data
        img = nib.load(chosen_file)
        data = img.get_fdata()
        X, Y, Z, T = data.shape

        # Create and apply brain mask
        mask_3d = make_brain_mask(data)
        data = data * mask_3d[..., None]

        # Subject-level normalization
        brain_values = data[mask_3d].ravel()
        if len(brain_values) > 0:
            min_val, max_val = np.min(brain_values), np.max(brain_values)
            if max_val > min_val:
                data = (data - min_val) / (max_val - min_val)
        else:
            print(f"⚠ Empty brain mask for {site}/{subj_dir}")
            continue

        # Select middle time frames
        if T < N_TIME:
            print(f"⚠ Insufficient timepoints ({T} < {N_TIME}) for {site}/{subj_dir}")
            continue
        start_t = (T - N_TIME) // 2
        time_points = range(start_t, start_t + N_TIME)

        # Determine slice indices based on brain coverage
        xs = np.where(mask_3d.any(axis=(1,2)))[0]
        ys = np.where(mask_3d.any(axis=(0,2)))[0]
        zs = np.where(mask_3d.any(axis=(0,1)))[0]
        if len(xs)==0 or len(ys)==0 or len(zs)==0:
            print(f"⚠ Empty axis in brain mask for {site}/{subj_dir}")
            continue
        x_slices = np.linspace(xs.min(), xs.max(), N_SLICE).astype(int)
        y_slices = np.linspace(ys.min(), ys.max(), N_SLICE).astype(int)
        z_slices = np.linspace(zs.min(), zs.max(), N_SLICE).astype(int)

        # Prepare output directory
        os.makedirs(output_dir, exist_ok=True)

        # Process each timepoint and slice
        for t_idx, t in enumerate(time_points):
            for s_idx in range(N_SLICE):
                xy = data[:, :, z_slices[s_idx], t]
                xz = data[:, y_slices[s_idx], :, t]
                yz = data[x_slices[s_idx], :, :, t]
                r = process_slice(xy, OUT_SIZE)
                g = process_slice(xz, OUT_SIZE)
                b = process_slice(yz, OUT_SIZE)
                rgb = np.stack([r, g, b], axis=-1)
                rgb = (rgb * 255).clip(0,255).astype(np.uint8)
                fname = f"tp{t_idx:02d}_sl{s_idx:02d}.png"
                Image.fromarray(rgb).save(os.path.join(output_dir, fname))

        # Verify
        created = glob(os.path.join(output_dir, "*.png"))
        print(f"✅ Created {len(created)} slices for {site}/{subj_dir}")

print("=== PROCESSING COMPLETE ===")
# Out:
# Processing site: KKI
# ✅ Skipping KKI/1018959 (already has 2500 slices)
# ✅ Skipping KKI/1019436 (already has 2500 slices)
# ✅ Skipping KKI/1043241 (already has 2500 slices)
# ✅ Skipping KKI/1266183 (already has 2500 slices)
# ✅ Skipping KKI/1535233 (already has 2500 slices)
# ✅ Skipping KKI/1541812 (already has 2500 slices)
# ✅ Skipping KKI/1577042 (already has 2500 slices)
# ✅ Skipping KKI/1594156 (already has 2500 slices)
# ✅ Skipping KKI/1623716 (already has 2500 slices)
# ✅ Skipping KKI/1638334 (already has 2500 slices)
# ✅ Skipping KKI/1652369 (already has 2500 slices)
# ✅ Skipping KKI/1686265 (already has 2500 slices)
# ✅ Skipping KKI/1692275 (already has 2500 slices)
# ✅ Skipping KKI/1735881 (already has 2500 slices)
# ✅ Skipping KKI/1779922 (already has 2500 slices)
# ✅ Skipping KKI/1842819 (already has 2500 slices)
# ✅ Skipping KKI/1846346 (already has 2500 slices)
# ✅ Skipping KKI/1873761 (already has 2500 slices)
# ✅ Skipping KKI/1962503 (already has 2500 slices)
# ✅ Skipping KKI/1988015 (already has 2500 slices)
# ✅ Skipping KKI/1996183 (already has 2500 slices)
# ✅ Skipping KKI/2014113 (already has 2500 slices)
# ✅ Skipping KKI/2018106 (already has 2500 slices)
# ✅ Skipping KKI/2026113 (already has 2500 slices)
# ✅ Skipping KKI/2081148 (already has 2500 slices)
# ✅ Skipping KKI/2104012 (already has 2500 slices)
# ✅ Skipping KKI/2138826 (already has 2500 slices)
# ✅ Skipping KKI/2299519 (already has 2500 slices)
# ✅ Skipping KKI/2344857 (already has 2500 slices)
# ✅ Skipping KKI/2360428 (already has 2500 slices)
# ✅ Skipping KKI/2371032 (already has 2500 slices)
# ✅ Skipping KKI/2554127 (already has 2500 slices)
# ✅ Skipping KKI/2558999 (already has 2500 slices)
# ✅ Skipping KKI/2572285 (already has 2500 slices)
# ✅ Skipping KKI/2601925 (already has 2500 slices)
# ✅ Skipping KKI/2618929 (already has 2500 slices)
# ✅ Skipping KKI/2621228 (already has 2500 slices)
# ✅ Skipping KKI/2640795 (already has 2500 slices)
# ✅ Skipping KKI/2641332 (already has 2500 slices)
# ✅ Skipping KKI/2703289 (already has 2500 slices)
# ✅ Skipping KKI/2740232 (already has 2500 slices)
# ✅ Skipping KKI/2768273 (already has 2500 slices)
# ✅ Skipping KKI/2822304 (already has 2500 slices)
# ✅ Skipping KKI/2903997 (already has 2500 slices)
# ✅ Skipping KKI/2917777 (already has 2500 slices)
# ✅ Skipping KKI/2930625 (already has 2500 slices)
# ✅ Skipping KKI/3103809 (already has 2500 slices)
# ✅ Skipping KKI/3119327 (already has 2500 slices)
# ✅ Skipping KKI/3154996 (already has 2500 slices)
# ✅ Skipping KKI/3160561 (already has 2500 slices)
# ✅ Skipping KKI/3170319 (already has 2500 slices)
# ✅ Skipping KKI/3310328 (already has 2500 slices)
# ✅ Skipping KKI/3434578 (already has 2500 slices)
# ✅ Skipping KKI/3486975 (already has 2500 slices)
# ✅ Skipping KKI/3519022 (already has 2500 slices)
# ✅ Skipping KKI/3611827 (already has 2500 slices)
# ✅ Skipping KKI/3699991 (already has 2500 slices)
# ✅ Skipping KKI/3713230 (already has 2500 slices)
# ✅ Skipping KKI/3813783 (already has 2500 slices)
# ✅ Skipping KKI/3884955 (already has 2500 slices)
# ✅ Skipping KKI/3902469 (already has 2500 slices)
# ✅ Skipping KKI/3912996 (already has 2500 slices)
# ✅ Skipping KKI/3917422 (already has 2500 slices)
# ✅ Skipping KKI/3972472 (already has 2500 slices)
# ✅ Skipping KKI/3972956 (already has 2500 slices)
# ✅ Skipping KKI/4104523 (already has 2500 slices)
# ✅ Skipping KKI/4154182 (already has 2500 slices)
# ✅ Skipping KKI/4275075 (already has 2500 slices)
# ✅ Skipping KKI/4362730 (already has 2500 slices)
# ✅ Skipping KKI/4601682 (already has 2500 slices)
# ✅ Skipping KKI/5216908 (already has 2500 slices)
# ✅ Skipping KKI/6346605 (already has 2500 slices)
# ✅ Skipping KKI/6453038 (already has 2500 slices)
# ✅ Skipping KKI/7129258 (already has 2500 slices)
# ✅ Skipping KKI/7415617 (already has 2500 slices)
# ✅ Skipping KKI/7774305 (already has 2500 slices)
# ✅ Skipping KKI/8083695 (already has 2500 slices)
# ✅ Skipping KKI/8263351 (already has 2500 slices)
# ✅ Skipping KKI/8337695 (already has 2500 slices)
# ✅ Skipping KKI/8432725 (already has 2500 slices)
# ✅ Skipping KKI/8628223 (already has 2500 slices)
# ✅ Skipping KKI/8658218 (already has 2500 slices)
# ✅ Skipping KKI/9922944 (already has 2500 slices)
# Processing site: NeuroIMAGE
# ✅ Skipping NeuroIMAGE/1017176 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE
# ✅ Skipping NYU/2773205 (already has 2500 slices)
# ✅ Skipping NYU/2821683 (already has 2500 slices)
# ✅ Skipping NYU/2854839 (already has 2500 slices)
# ✅ Skipping NYU/2907383 (already has 2500 slices)
# ✅ Skipping NYU/2950672 (already has 2500 slices)
# ✅ Skipping NYU/2983819 (already has 2500 slices)
# ✅ Skipping NYU/2991307 (already has 2500 slices)
# ✅ Skipping NYU/2996531 (already has 2500 slices)
# ✅ Skipping NYU/3011311 (already has 2500 slices)
# ✅ Skipping NYU/3163200 (already has 2500 slices)
# ✅ Skipping NYU/3174224 (already has 2500 slices)
# ✅ Skipping NYU/3235580 (already has 2500 slices)
# ✅ Skipping NYU/3243657 (already has 2500 slices)
# ✅ Skipping NYU/3349205 (already has 2500 slices)
# ✅ Skipping NYU/3349423 (already has 2500 slices)
# ✅ Skipping NYU/3433846 (already has 2500 slices)
# ✅ Skipping NYU/3441455 (already has 2500 slices)
# ✅ Skipping NYU/3457975 (already has 2500 slices)
# ✅ Skipping NYU/3518345 (already has 2500 slices)
# ✅ Skipping NYU/3542588 (already has 2500 slices)
# ✅ Skipping NYU/3601861 (already has 2500 slices)
# ✅ Skipping NYU/3619797 (already has 2500 slices)
# ✅ Skipping NYU/3650634 (already has 2500 slices)
# ✅ Skipping NYU/3653737 (already has 2500 slices)
# ✅ Skipping NYU/3662296 (already has 2500 slices)
# ✅ Skipping NYU/3679455 (already has 2500 slices)
# ✅ Skipping NYU/3845761 (already has 2500 slices)
# ✅ Skipping NYU/3999344 (already has 2500 slices)
# ✅ Skipping NYU/4060823 (already has 2500 slices)
# ✅ Skipping NYU/4079254 (already has 2500 slices)
# ✅ Skipping NYU/4084645 (already has 2500 slices)
# ✅ Skipping NYU/4095229 (already has 2500 slices)
# ✅ Skipping NYU/4116166 (already has 2500 slices)
# ✅ Skipping NYU/4154672 (already has 2500 slices)
# ✅ Skipping NYU/4164316 (already has 2500 slices)
# ✅ Skipping NYU/4187857 (already has 2500 slices)
# ✅ Skipping NYU/4562206 (already has 2500 slices)
# ✅ Skipping NYU/4827048 (already has 2500 slices)
# ✅ Skipping NYU/5164727 (already has 2500 slices)
# ✅ Skipping NYU/5971050 (already has 2500 slices)
# ✅ Skipping NYU/6206397 (already has 2500 slices)
# ✅ Skipping NYU/6568351 (already has 2500 slices)
# ✅ Skipping NYU/8009688 (already has 2500 slices)
# ✅ Skipping NYU/8415034 (already has 2500 slices)
# ✅ Skipping NYU/8692452 (already has 2500 slices)
# ✅ Skipping NYU/8697774 (already has 2500 slices)
# ✅ Skipping NYU/8834383 (already has 2500 slices)
# ✅ Skipping NYU/8915162 (already has 2500 slices)
# ✅ Skipping NYU/9326955 (already has 2500 slices)
# ✅ Skipping NYU/9578663 (already has 2500 slices)
# ✅ Skipping NYU/9750701 (already has 2500 slices)
# ✅ Skipping NYU/9907452 (already has 2500 slices)
# Processing: NYU/0010001 with sfnwmrda0010001_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010001
# Processing: NYU/0010003 with sfnwmrda0010003_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0010003
# Processing: NYU/0010004 with sfnwmrda0010004_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010004
# Processing: NYU/0010005 with sfnwmrda0010005_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0
session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010071
# Processing: NYU/0010033 with sfnwmrda0010033_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010033
# Processing: NYU/0010072 with sfnwmrda0010072_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0010072
# Processing: NYU/0010073 with sfnwmrda0010073_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010073
# Processing: NYU/0010104 with sfnwmrda0010104_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010104
# Processing: NYU/0010088 with sfnwmrda0010088_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010088
# Processing: NYU/0010040 with sfnwmrda0010040_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010040
# Processing: NYU/0010124 with sfnwmrda0010124_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010124
# Processing: NYU/0010041 with sfnwmrda0010041_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0010041
# Processing: NYU/0010125 with sfnwmrda0010125_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010125
# Processing: NYU/0010007 with sfnwmrda0010007_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010007
# Processing: NYU/0010126 with sfnwmrda0010126_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0010126
# ⚠ No NIFTI files for NYU/0010127
# Processing: NYU/0010128 with sfnwmrda0010128_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/0010128
# Processing: NYU/0010129 with sfnwmrda0010129_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010129
# Processing: NYU/0010013 with sfnwmrda0010013_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010013
# Processing: NYU/0010043 with sfnwmrda0010043_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/0010043
# Processing site: OHSU
# ✅ Skipping OHSU/1084283 (already has 2500 slices)
# ✅ Skipping OHSU/1084884 (already has 2500 slices)
# ✅ Skipping OHSU/1108916 (already has 2500 slices)
# ✅ Skipping OHSU/1206380 (already has 2500 slices)
# ✅ Skipping OHSU/1340333 (already has 2500 slices)
# ✅ Skipping OHSU/1386056 (already has 2500 slices)
# ✅ Skipping OHSU/1411223 (already has 2500 slices)
# ✅ Skipping OHSU/1418396 (already has 2500 slices)
# ✅ Skipping OHSU/1421489 (already has 2500 slices)
# ✅ Skipping OHSU/1481430 (already has 2500 slices)
# ✅ Skipping OHSU/1502229 (already has 2500 slices)
# ✅ Skipping OHSU/1536593 (already has 2500 slices)
# ✅ Skipping OHSU/1548937 (already has 2500 slices)
# ✅ Skipping OHSU/1552181 (already has 2500 slices)
# ✅ Skipping OHSU/1647968 (already has 2500 slices)
# ✅ Skipping OHSU/1664335 (already has 2500 slices)
# ✅ Skipping OHSU/1679142 (already has 2500 slices)
# ✅ Skipping OHSU/1696588 (already has 2500 slices)
# ✅ Skipping OHSU/1743472 (already has 2500 slices)
# ✅ Skipping OHSU/2054310 (already has 2500 slices)
# ✅ Skipping OHSU/2054998 (already has 2500 slices)
# ✅ Skipping OHSU/2071989 (already has 2500 slices)
# ✅ Skipping OHSU/2124248 (already has 2500 slices)
# ✅ Skipping OHSU/2155356 (already has 2500 slices)
# ✅ Skipping OHSU/2232376 (already has 2500 slices)
# ✅ Skipping OHSU/2232413 (already has 2500 slices)
# ✅ Skipping OHSU/2288903 (already has 2500 slices)
# ✅ Skipping OHSU/2292940 (already has 2500 slices)
# ✅ Skipping OHSU/2409220 (already has 2500 slices)
# ✅ Skipping OHSU/2415970 (already has 2500 slices)
# ✅ Skipping OHSU/2426523 (already has 2500 slices)
# ✅ Skipping OHSU/2427434 (already has 2500 slices)
# ✅ Skipping OHSU/2455205 (already has 2500 slices)
# ✅ Skipping OHSU/2535204 (already has 2500 slices)
# ✅ Skipping OHSU/2559559 (already has 2500 slices)
# ✅ Skipping OHSU/2561174 (already has 2500 slices)
# ✅ Skipping OHSU/2571197 (already has 2500 slices)
# ✅ Skipping OHSU/2578455 (already has 2500 slices)
# ✅ Skipping OHSU/2620872 (already has 2500 slices)
# ✅ Skipping OHSU/2790141 (already has 2500 slices)
# ✅ Skipping OHSU/2845989 (already has 2500 slices)
# ✅ Skipping OHSU/2920716 (already has 2500 slices)
# ✅ Skipping OHSU/2929195 (already has 2500 slices)
# ✅ Skipping OHSU/2947936 (already has 2500 slices)
# ✅ Skipping OHSU/2959809 (already has 2500 slices)
# ✅ Skipping OHSU/3048401 (already has 2500 slices)
# ✅ Skipping OHSU/3051944 (already has 2500 slices)
# ✅ Skipping OHSU/3052540 (already has 2500 slices)
# ✅ Skipping OHSU/3162671 (already has 2500 slices)
# ✅ Skipping OHSU/3206978 (already has 2500 slices)
# ✅ Skipping OHSU/3212875 (already has 2500 slices)
# ✅ Skipping OHSU/3244985 (already has 2500 slices)
# ✅ Skipping OHSU/3286474 (already has 2500 slices)
# ✅ Skipping OHSU/3302025 (already has 2500 slices)
# ✅ Skipping OHSU/3358877 (already has 2500 slices)
# ✅ Skipping OHSU/3466651 (already has 2500 slices)
# ✅ Skipping OHSU/3470141 (already has 2500 slices)
# ✅ Skipping OHSU/3560456 (already has 2500 slices)
# ✅ Skipping OHSU/3652932 (already has 2500 slices)
# ✅ Skipping OHSU/3677724 (already has 2500 slices)
# ✅ Skipping OHSU/3684229 (already has 2500 slices)
# ✅ Skipping OHSU/3812101 (already has 2500 slices)
# ✅ Skipping OHSU/3848511 (already has 2500 slices)
# ✅ Skipping OHSU/3869075 (already has 2500 slices)
# ✅ Skipping OHSU/3899622 (already has 2500 slices)
# ✅ Skipping OHSU/4016887 (already has 2500 slices)
# ✅ Skipping OHSU/4046678 (already has 2500 slices)
# ✅ Skipping OHSU/4072305 (already has 2500 slices)
# ✅ Skipping OHSU/4103874 (already has 2500 slices)
# ✅ Skipping OHSU/4219416 (already has 2500 slices)
# ✅ Skipping OHSU/4529116 (already has 2500 slices)
# ✅ Skipping OHSU/5302451 (already has 2500 slices)
# ✅ Skipping OHSU/6592761 (already has 2500 slices)
# ✅ Skipping OHSU/6953386 (already has 2500 slices)
# ✅ Skipping OHSU/7333005 (already has 2500 slices)
# ✅ Skipping OHSU/8064456 (already has 2500 slices)
# ✅ Skipping OHSU/8218392 (already has 2500 slices)
# ✅ Skipping OHSU/8720244 (already has 2500 slices)
# ✅ Skipping OHSU/9499804 (already has 2500 slices)
# Processing site: Peking_1
# ✅ Skipping Peking_1/1056121 (already has 2500 slices)
# ✅ Skipping Peking_1/1113498 (already has 2500 slices)
# ✅ Skipping Peking_1/1133221 (already has 2500 slices)
# ✅ Skipping Peking_1/1139030 (already has 2500 slices)
# ✅ Skipping Peking_1/1186237 (already has 2500 slices)
# ✅ Skipping Peking_1/1240299 (already has 2500 slices)
# ✅ Skipping Peking_1/1258069 (already has 2500 slices)
# ✅ Skipping Peking_1/1282248 (already has 2500 slices)
# ✅ Skipping Peking_1/1302449 (already has 2500 slices)
# ✅ Skipping Peking_1/1391181 (already has 2500 slices)
# ✅ Skipping Peking_1/1408093 (already has 2500 slices)
# ✅ Skipping Peking_1/1469171 (already has 2500 slices)
# ✅ Skipping Peking_1/1561488 (already has 2500 slices)
# ✅ Skipping Peking_1/1686092 (already has 2500 slices)
# ✅ Skipping Peking_1/1689948 (already has 2500 slices)
# ✅ Skipping Peking_1/1791543 (already has 2500 slices)
# ✅ Skipping Peking_1/1805037 (already has 2500 slices)
# ✅ Skipping Peking_1/1875711 (already has 2500 slices)
# ✅ Skipping Peking_1/1879542 (already has 2500 slices)
# ✅ Skipping Peking_1/1912810 (already has 2500 slices)
# ✅ Skipping Peking_1/1947991 (already has 2500 slices)
# ✅ Skipping Peking_1/2081754 (already has 2500 slices)
# ✅ Skipping Peking_1/2106109 (already has 2500 slices)
# ✅ Skipping Peking_1/2123983 (already has 2500 slices)
# ✅ Skipping Peking_1/2174595 (already has 2500 slices)
# ✅ Skipping Peking_1/2196753 (already has 2500 slices)
# ✅ Skipping Peking_1/2240562 (already has 2500 slices)
# ✅ Skipping Peking_1/2249443 (already has 2500 slices)
# ✅ Skipping Peking_1/2266806 (already has 2500 slices)
# ✅ Skipping Peking_1/2367157 (already has 2500 slices)
# ✅ Skipping Peking_1/2408774 (already has 2500 slices)
# ✅ Skipping Peking_1/2427408 (already has 2500 slices)
# ✅ Skipping Peking_1/2535087 (already has 2500 slices)
# ✅ Skipping Peking_1/2538839 (already has 2500 slices)
# ✅ Skipping Peking_1/2697768 (already has 2500 slices)
# ✅ Skipping Peking_1/2703336 (already has 2500 slices)
# ✅ Skipping Peking_1/2714224 (already has 2500 slices)
# ✅ Skipping Peking_1/2833684 (already has 2500 slices)
# ✅ Skipping Peking_1/2897046 (already has 2500 slices)
# ✅ Skipping Peking_1/2910270 (already has 2500 slices)
# ✅ Skipping Peking_1/3004580 (already has 2500 slices)
# ✅ Skipping Peking_1/3086074 (already has 2500 slices)
# ✅ Skipping Peking_1/3212536 (already has 2500 slices)
# ✅ Skipping Peking_1/3233028 (already has 2500 slices)
# ✅ Skipping Peking_1/3239413 (already has 2500 slices)
# ✅ Skipping Peking_1/3262042 (already has 2500 slices)
# ✅ Skipping Peking_1/3269608 (already has 2500 slices)
# ✅ Skipping Peking_1/3306863 (already has 2500 slices)
# ✅ Skipping Peking_1/3390312 (already has 2500 slices)
# ✅ Skipping Peking_1/3554582 (already has 2500 slices)
# ✅ Skipping Peking_1/3587000 (already has 2500 slices)
# ✅ Skipping Peking_1/3593327 (already has 2500 slices)
# ✅ Skipping Peking_1/3672854 (already has 2500 slices)
# ✅ Skipping Peking_1/3707771 (already has 2500 slices)
# ✅ Skipping Peking_1/3732101 (already has 2500 slices)
# ✅ Skipping Peking_1/3739175 (already has 2500 slices)
# ✅ Skipping Peking_1/3809753 (already has 2500 slices)
# ✅ Skipping Peking_1/3889095 (already has 2500 slices)
# ✅ Skipping Peking_1/3967265 (already has 2500 slices)
# ✅ Skipping Peking_1/3976121 (already has 2500 slices)
# ✅ Skipping Peking_1/3983607 (already has 2500 slices)
# ✅ Skipping Peking_1/4028266 (already has 2500 slices)
# ✅ Skipping Peking_1/4053836 (already has 2500 slices)
# ✅ Skipping Peking_1/4091983 (already has 2500 slices)
# ✅ Skipping Peking_1/4095748 (already has 2500 slices)
# ✅ Skipping Peking_1/4256491 (already has 2500 slices)
# ✅ Skipping Peking_1/4334113 (already has 2500 slices)
# ✅ Skipping Peking_1/4383707 (already has 2500 slices)
# ✅ Skipping Peking_1/4475709 (already has 2500 slices)
# ✅ Skipping Peking_1/4921428 (already has 2500 slices)
# ✅ Skipping Peking_1/5150328 (already has 2500 slices)
# ✅ Skipping Peking_1/5193577 (already has 2500 slices)
# ✅ Skipping Peking_1/5600820 (already has 2500 slices)
# ✅ Skipping Peking_1/6187322 (already has 2500 slices)
# ✅ Skipping Peking_1/7093319 (already has 2500 slices)
# ✅ Skipping Peking_1/7135128 (already has 2500 slices)
# ✅ Skipping Peking_1/7390867 (already has 2500 slices)
# ✅ Skipping Peking_1/8328877 (already has 2500 slices)
# ✅ Skipping Peking_1/8838009 (already has 2500 slices)
# ✅ Skipping Peking_1/9093997 (already has 2500 slices)
# ✅ Skipping Peking_1/9210521 (already has 2500 slices)
# ✅ Skipping Peking_1/9221927 (already has 2500 slices)
# ✅ Skipping Peking_1/9783279 (already has 2500 slices)
# ✅ Skipping Peking_1/9887336 (already has 2500 slices)
# ✅ Skipping Peking_1/9890726 (already has 2500 slices)
# Processing site: Peking_2
# ✅ Skipping Peking_2/3655623 (already has 2500 slices)
# ✅ Skipping Peking_2/3248920 (already has 2500 slices)
# ✅ Skipping Peking_2/2659769 (already has 2500 slices)
# ✅ Skipping Peking_2/9640133 (already has 2500 slices)
# ✅ Skipping Peking_2/4055710 (already has 2500 slices)
# ✅ Skipping Peking_2/1050975 (already has 2500 slices)
# ✅ Skipping Peking_2/1809715 (already has 2500 slices)
# ✅ Skipping Peking_2/1916266 (already has 2500 slices)
# ✅ Skipping Peking_2/1117299 (already has 2500 slices)
# ✅ Skipping Peking_2/2559537 (already has 2500 slices)
# ✅ Skipping Peking_2/2296326 (already has 2500 slices)
# ✅ Skipping Peking_2/7407032 (already has 2500 slices)
# ✅ Skipping Peking_2/3157406 (already has 2500 slices)
# ✅ Skipping Peking_2/3994098 (already has 2500 slices)
# ✅ Skipping Peking_2/3561920 (already has 2500 slices)
# ✅ Skipping Peking_2/2140063 (already has 2500 slices)
# ✅ Skipping Peking_2/3610134 (already has 2500 slices)
# ✅ Skipping Peking_2/3494778 (already has 2500 slices)
# ✅ Skipping Peking_2/2033178 (already has 2500 slices)
# ✅ Skipping Peking_2/1562298 (already has 2500 slices)
# ✅ Skipping Peking_2/1093743 (already has 2500 slices)
# ✅ Skipping Peking_2/1177160 (already has 2500 slices)
# ✅ Skipping Peking_2/1860323 (already has 2500 slices)
# ✅ Skipping Peking_2/1494102 (already has 2500 slices)
# ✅ Skipping Peking_2/2498847 (already has 2500 slices)
# ✅ Skipping Peking_2/1875013 (already has 2500 slices)
# ✅ Skipping Peking_2/1068505 (already has 2500 slices)
# ✅ Skipping Peking_2/3993793 (already has 2500 slices)
# ✅ Skipping Peking_2/2310449 (already has 2500 slices)
# ✅ Skipping Peking_2/3308331 (already has 2500 slices)
# ✅ Skipping Peking_2/4265987 (already has 2500 slices)
# ✅ Skipping Peking_2/3562883 (already has 2500 slices)
# ✅ Skipping Peking_2/9578631 (already has 2500 slices)
# ✅ Skipping Peking_2/2377207 (already has 2500 slices)
# ✅ Skipping Peking_2/7011503 (already has 2500 slices)
# ✅ Skipping Peking_2/8278680 (already has 2500 slices)
# ✅ Skipping Peking_2/4075719 (already has 2500 slices)
# ✅ Skipping Peking_2/2737106 (already has 2500 slices)
# ✅ Skipping Peking_2/1159908 (already has 2500 slices)
# ✅ Skipping Peking_2/4053388 (already has 2500 slices)
# ✅ Skipping Peking_2/7689953 (already has 2500 slices)
# ✅ Skipping Peking_2/2884672 (already has 2500 slices)
# ✅ Skipping Peking_2/2601519 (already has 2500 slices)
# ✅ Skipping Peking_2/2529026 (already has 2500 slices)
# ✅ Skipping Peking_2/6500128 (already has 2500 slices)
# ✅ Skipping Peking_2/1628610 (already has 2500 slices)
# ✅ Skipping Peking_2/3691107 (already has 2500 slices)
# ✅ Skipping Peking_2/4221029 (already has 2500 slices)
# ✅ Skipping Peking_2/3856956 (already has 2500 slices)
# ✅ Skipping Peking_2/1643780 (already has 2500 slices)
# ✅ Skipping Peking_2/3910672 (already has 2500 slices)
# ✅ Skipping Peking_2/3194757 (already has 2500 slices)
# ✅ Skipping Peking_2/2141250 (already has 2500 slices)
# ✅ Skipping Peking_2/9002207 (already has 2500 slices)
# ✅ Skipping Peking_2/3446674 (already has 2500 slices)
# ✅ Skipping Peking_2/2031422 (already has 2500 slices)
# ✅ Skipping Peking_2/4073815 (already has 2500 slices)
# ✅ Skipping Peking_2/1341865 (already has 2500 slices)
# ✅ Skipping Peking_2/7253183 (already has 2500 slices)
# ✅ Skipping Peking_2/5993008 (already has 2500 slices)
# ✅ Skipping Peking_2/4225073 (already has 2500 slices)
# ✅ Skipping Peking_2/1094669 (already has 2500 slices)
# ✅ Skipping Peking_2/2950754 (already has 2500 slices)
# ✅ Skipping Peking_2/2207418 (already has 2500 slices)
# ✅ Skipping Peking_2/2919220 (already has 2500 slices)
# ✅ Skipping Peking_2/3827352 (already has 2500 slices)
# ✅ Skipping Peking_2/3205761 (already has 2500 slices)
# Processing site: WashU
# Processing: WashU/0015001 with sfnwmrda0015001_session_4_rest_6.nii.gz
# ✅ Created 2500 slices for WashU/0015001
# Processing: WashU/0015002 with sfnwmrda0015002_session_1_rest_6.nii.gz
# ✅ Created 2500 slices for WashU/0015002
# Processing: WashU/0015003 with sfnwmrda0015003_session_1_rest_6.nii.gz
# ✅ Created 2500 slices for WashU/0015003
# Processing: WashU/0015004 with sfnwmrda0015004_session_2_rest_6.nii.gz
# ✅ Created 2500 slices for WashU/0015004
# Processing: WashU/0015005 with sfnwmrda0015005_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015005
# Processing: WashU/0015006 with sfnwmrda0015006_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015006
# Processing: WashU/0015007 with sfnwmrda0015007_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015007
# Processing: WashU/0015008 with sfnwmrda0015008_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015008
# Processing: WashU/0015010 with sfnwmrda0015010_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015010
# ⚠ No NIFTI files for WashU/0015011
# Processing: WashU/0015012 with sfnwmrda0015012_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015012
# Processing: WashU/0015013 with sfnwmrda0015013_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015013
# Processing: WashU/0015014 with sfnwmrda0015014_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015014
# Processing: WashU/0015015 with sfnwmrda0015015_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015015
# Processing: WashU/0015016 with sfnwmrda0015016_session_2_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015016
# Processing: WashU/0015017 with sfnwmrda0015017_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015017
# ⚠ No NIFTI files for WashU/0015018
# Processing: WashU/0015019 with sfnwmrda0015019_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015019
# Processing: WashU/0015020 with sfnwmrda0015020_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015020
# Processing: WashU/0015021 with sfnwmrda0015021_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015021
# Processing: WashU/0015022 with sfnwmrda0015022_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015022
# Processing: WashU/0015023 with sfnwmrda0015023_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015023
# Processing: WashU/0015024 with sfnwmrda0015024_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015024
# Processing: WashU/0015025 with sfnwmrda0015025_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015025
# Processing: WashU/0015026 with sfnwmrda0015026_session_3_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015026
# Processing: WashU/0015027 with sfnwmrda0015027_session_2_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015027
# Processing: WashU/0015028 with sfnwmrda0015028_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015028
# Processing: WashU/0015029 with sfnwmrda0015029_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015029
# Processing: WashU/0015030 with sfnwmrda0015030_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015030
# Processing: WashU/0015031 with sfnwmrda0015031_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015031
# Processing: WashU/0015032 with sfnwmrda0015032_session_2_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015032
# Processing: WashU/0015033 with sfnwmrda0015033_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015033
# Processing: WashU/0015034 with sfnwmrda0015034_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015034
# Processing: WashU/0015035 with sfnwmrda0015035_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015035
# Processing: WashU/0015036 with sfnwmrda0015036_session_2_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015036
# Processing: WashU/0015037 with sfnwmrda0015037_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015037
# Processing: WashU/0015038 with sfnwmrda0015038_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for WashU/0015038
# Processing: WashU/0015039 with sfnwmrda0015039_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015039
# Processing: WashU/0015040 with sfnwmrda0015040_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015040
# Processing: WashU/0015041 with sfnwmrda0015041_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015041
# Processing: WashU/0015042 with sfnwmrda0015042_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015042
# Processing: WashU/0015043 with sfnwmrda0015043_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015043
# Processing: WashU/0015044 with sfnwmrda0015044_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015044
# Processing: WashU/0015045 with sfnwmrda0015045_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015045
# Processing: WashU/0015046 with sfnwmrda0015046_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015046
# Processing: WashU/0015047 with sfnwmrda0015047_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015047
# Processing: WashU/0015048 with sfnwmrda0015048_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015048
# Processing: WashU/0015049 with sfnwmrda0015049_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015049
# Processing: WashU/0015050 with sfnwmrda0015050_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015050
# Processing: WashU/0015051 with sfnwmrda0015051_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015051
# Processing: WashU/0015052 with sfnwmrda0015052_session_2_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015052
# Processing: WashU/0015053 with sfnwmrda0015053_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015053
# Processing: WashU/0015054 with sfnwmrda0015054_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015054
# Processing: WashU/0015055 with sfnwmrda0015055_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015055
# Processing: WashU/0015056 with sfnwmrda0015056_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for WashU/0015056
# Processing: WashU/0015057 with sfnwmrda0015057_session_2_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015057
# Processing: WashU/0015058 with sfnwmrda0015058_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015058
# Processing: WashU/0015059 with sfnwmrda0015059_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015059
# Processing: WashU/0015060 with sfnwmrda0015060_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015060
# Processing: WashU/0015061 with sfnwmrda0015061_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015061
# Processing: WashU/0015062 with sfnwmrda0015062_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for WashU/0015062
# === PROCESSING COMPLETE ===
