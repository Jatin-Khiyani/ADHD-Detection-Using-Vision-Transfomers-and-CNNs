# %%
import os
import re
import numpy as np
import pandas as pd
import nibabel as nib
from glob import glob
from scipy.ndimage import binary_closing, binary_fill_holes
from skimage.transform import resize
from PIL import Image

# ─── CONFIG ───────────────────────────────────────────────────────────
BASE_IN  = "/Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd"
SITES    = ["KKI","NeuroIMAGE","NYU","OHSU","Peking_1","Peking_2","WashU"]
CSV_MAP  = {s: os.path.join(BASE_IN, s, f"{s}_phenotypic.csv") for s in SITES}

BASE_OUT = os.path.join(BASE_IN, "Slices")
N_TIME   = 50     # number of timepoints to extract (middle frames)
N_SLICE  = 50     # number of slices per axis
OUT_SIZE = (224, 224)
EXPECTED_SLICES = N_TIME * N_SLICE  # 2500 slices per subject

# ─── HELPERS ───────────────────────────────────────────────────────────
def pick_latest_run(files):
    """Select the nifti file with the highest session/run numbers"""
    def key(f):
        m = re.search(r"session_(\d+)_rest_(\d+)", f)
        return (int(m.group(1)), int(m.group(2))) if m else (-1, -1)
    return sorted(files, key=key)[-1] if files else None

def make_brain_mask(vol4d):
    """Create 3D brain mask from 4D fMRI data"""
    mean_vol = vol4d.mean(axis=3)
    m0 = mean_vol > 0
    m1 = binary_closing(m0, iterations=2)
    return binary_fill_holes(m1)

def process_slice(slice_data, out_size):
    """Process individual slice with masking after resizing"""
    # Resize and create mask
    resized = resize(slice_data, out_size, preserve_range=True)
    mask = resize((slice_data > 0).astype(float), out_size, order=0, preserve_range=True) > 0.5
    
    # Apply mask to set background to zero
    resized[~mask] = 0
    return resized

# ─── MAIN PROCESSING ──────────────────────────────────────────────────
for site in SITES:
    print(f"Processing site: {site}")
    csv_path = CSV_MAP[site]
    
    # Handle missing CSV files
    if not os.path.exists(csv_path):
        print(f"⚠ CSV not found: {csv_path}")
        continue
        
    df = pd.read_csv(csv_path)
    subj_col = df.columns[0]  # First column contains subject IDs

    for subj in df[subj_col].astype(str):
        subj_path = os.path.join(BASE_IN, site, subj)
        output_dir = os.path.join(BASE_OUT, site, subj)
        
        # Check if subject already has complete set of slices
        if os.path.exists(output_dir):
            existing_files = glob(os.path.join(output_dir, "*.png"))
            if len(existing_files) >= EXPECTED_SLICES:
                print(f"✅ Skipping {site}/{subj} (already has {len(existing_files)} slices)")
                continue
        
        if not os.path.isdir(subj_path):
            print(f"⚠ Subject dir missing: {subj_path}")
            continue

        # Find and select the best run
        runs = glob(os.path.join(subj_path, "*.nii.gz"))
        if not runs:
            print(f"⚠ No NIFTI files for {site}/{subj}")
            continue
            
        chosen_file = pick_latest_run(runs)
        print(f"Processing: {site}/{subj} with {os.path.basename(chosen_file)}")

        # Load and prepare data
        img = nib.load(chosen_file)
        data = img.get_fdata()
        X, Y, Z, T = data.shape

        # Create and apply brain mask
        mask_3d = make_brain_mask(data)
        data = data * mask_3d[..., None]  # Apply mask to all timepoints

        # Subject-level normalization
        brain_values = data[mask_3d].ravel()
        if len(brain_values) > 0:
            min_val, max_val = np.min(brain_values), np.max(brain_values)
            if max_val > min_val:
                data = (data - min_val) / (max_val - min_val)
            else:
                data = data.copy()  # Avoid modifying original if no scaling
        else:
            print(f"⚠ Empty brain mask for {site}/{subj}")
            continue

        # Select middle time frames
        if T < N_TIME:
            print(f"⚠ Insufficient timepoints ({T} < {N_TIME}) for {site}/{subj}")
            continue
            
        start_t = (T - N_TIME) // 2
        time_points = range(start_t, start_t + N_TIME)

        # Determine slice indices based on brain coverage
        xs = np.where(mask_3d.any(axis=(1,2)))[0]
        ys = np.where(mask_3d.any(axis=(0,2)))[0]
        zs = np.where(mask_3d.any(axis=(0,1)))[0]
        
        if len(xs) == 0 or len(ys) == 0 or len(zs) == 0:
            print(f"⚠ Empty axis in brain mask for {site}/{subj}")
            continue
            
        x_slices = np.linspace(xs.min(), xs.max(), N_SLICE).astype(int)
        y_slices = np.linspace(ys.min(), ys.max(), N_SLICE).astype(int)
        z_slices = np.linspace(zs.min(), zs.max(), N_SLICE).astype(int)

        # Prepare output directory
        os.makedirs(output_dir, exist_ok=True)

        # Process each timepoint and slice
        for t_idx, t in enumerate(time_points):
            for s_idx in range(N_SLICE):
                # Extract orthogonal slices
                xy_slice = data[:, :, z_slices[s_idx], t]  # Axial (XY)
                xz_slice = data[:, y_slices[s_idx], :, t]  # Coronal (XZ)
                yz_slice = data[x_slices[s_idx], :, :, t]  # Sagittal (YZ)

                # Process each slice with masking
                r = process_slice(xy_slice, OUT_SIZE)  # Red channel
                g = process_slice(xz_slice, OUT_SIZE)  # Green channel
                b = process_slice(yz_slice, OUT_SIZE)  # Blue channel

                # Combine into RGB and convert to 8-bit
                rgb = np.stack([r, g, b], axis=-1)
                rgb = (rgb * 255).clip(0, 255).astype(np.uint8)

                # Save as PNG
                fname = f"tp{t_idx:02d}_sl{s_idx:02d}.png"
                Image.fromarray(rgb).save(os.path.join(output_dir, fname))

        # Verify slice count after processing
        created_files = glob(os.path.join(output_dir, "*.png"))
        print(f"✅ Created {len(created_files)} slices for {site}/{subj}")

print("=== PROCESSING COMPLETE ===")
# Out:
# Processing site: KKI
# ✅ Skipping KKI/1018959 (already has 2500 slices)
# ✅ Skipping KKI/1019436 (already has 2500 slices)
# ✅ Skipping KKI/1043241 (already has 2500 slices)
# ✅ Skipping KKI/1266183 (already has 2500 slices)
# ✅ Skipping KKI/1535233 (already has 2500 slices)
# ✅ Skipping KKI/1541812 (already has 2500 slices)
# ✅ Skipping KKI/1577042 (already has 2500 slices)
# ✅ Skipping KKI/1594156 (already has 2500 slices)
# ✅ Skipping KKI/1623716 (already has 2500 slices)
# ✅ Skipping KKI/1638334 (already has 2500 slices)
# ✅ Skipping KKI/1652369 (already has 2500 slices)
# ✅ Skipping KKI/1686265 (already has 2500 slices)
# ✅ Skipping KKI/1692275 (already has 2500 slices)
# ✅ Skipping KKI/1735881 (already has 2500 slices)
# ✅ Skipping KKI/1779922 (already has 2500 slices)
# ✅ Skipping KKI/1842819 (already has 2500 slices)
# ✅ Skipping KKI/1846346 (already has 2500 slices)
# ✅ Skipping KKI/1873761 (already has 2500 slices)
# ✅ Skipping KKI/1962503 (already has 2500 slices)
# ✅ Skipping KKI/1988015 (already has 2500 slices)
# ✅ Skipping KKI/1996183 (already has 2500 slices)
# ✅ Skipping KKI/2014113 (already has 2500 slices)
# ✅ Skipping KKI/2018106 (already has 2500 slices)
# ✅ Skipping KKI/2026113 (already has 2500 slices)
# ✅ Skipping KKI/2081148 (already has 2500 slices)
# ✅ Skipping KKI/2104012 (already has 2500 slices)
# ✅ Skipping KKI/2138826 (already has 2500 slices)
# ✅ Skipping KKI/2299519 (already has 2500 slices)
# ✅ Skipping KKI/2344857 (already has 2500 slices)
# ✅ Skipping KKI/2360428 (already has 2500 slices)
# ✅ Skipping KKI/2371032 (already has 2500 slices)
# ✅ Skipping KKI/2554127 (already has 2500 slices)
# ✅ Skipping KKI/2558999 (already has 2500 slices)
# ✅ Skipping KKI/2572285 (already has 2500 slices)
# ✅ Skipping KKI/2601925 (already has 2500 slices)
# ✅ Skipping KKI/2618929 (already has 2500 slices)
# ✅ Skipping KKI/2621228 (already has 2500 slices)
# ✅ Skipping KKI/2640795 (already has 2500 slices)
# ✅ Skipping KKI/2641332 (already has 2500 slices)
# ✅ Skipping KKI/2703289 (already has 2500 slices)
# ✅ Skipping KKI/2740232 (already has 2500 slices)
# ✅ Skipping KKI/2768273 (already has 2500 slices)
# ✅ Skipping KKI/2822304 (already has 2500 slices)
# ✅ Skipping KKI/2903997 (already has 2500 slices)
# ✅ Skipping KKI/2917777 (already has 2500 slices)
# ✅ Skipping KKI/2930625 (already has 2500 slices)
# ✅ Skipping KKI/3103809 (already has 2500 slices)
# ✅ Skipping KKI/3119327 (already has 2500 slices)
# ✅ Skipping KKI/3154996 (already has 2500 slices)
# ✅ Skipping KKI/3160561 (already has 2500 slices)
# ✅ Skipping KKI/3170319 (already has 2500 slices)
# ✅ Skipping KKI/3310328 (already has 2500 slices)
# ✅ Skipping KKI/3434578 (already has 2500 slices)
# ✅ Skipping KKI/3486975 (already has 2500 slices)
# ✅ Skipping KKI/3519022 (already has 2500 slices)
# ✅ Skipping KKI/3611827 (already has 2500 slices)
# ✅ Skipping KKI/3699991 (already has 2500 slices)
# ✅ Skipping KKI/3713230 (already has 2500 slices)
# ✅ Skipping KKI/3813783 (already has 2500 slices)
# ✅ Skipping KKI/3884955 (already has 2500 slices)
# ✅ Skipping KKI/3902469 (already has 2500 slices)
# ✅ Skipping KKI/3912996 (already has 2500 slices)
# ✅ Skipping KKI/3917422 (already has 2500 slices)
# ✅ Skipping KKI/3972472 (already has 2500 slices)
# ✅ Skipping KKI/3972956 (already has 2500 slices)
# ✅ Skipping KKI/4104523 (already has 2500 slices)
# ✅ Skipping KKI/4154182 (already has 2500 slices)
# ✅ Skipping KKI/4275075 (already has 2500 slices)
# ✅ Skipping KKI/4362730 (already has 2500 slices)
# ✅ Skipping KKI/4601682 (already has 2500 slices)
# ✅ Skipping KKI/5216908 (already has 2500 slices)
# ✅ Skipping KKI/6346605 (already has 2500 slices)
# ✅ Skipping KKI/6453038 (already has 2500 slices)
# ✅ Skipping KKI/7129258 (already has 2500 slices)
# ✅ Skipping KKI/7415617 (already has 2500 slices)
# ✅ Skipping KKI/7774305 (already has 2500 slices)
# ✅ Skipping KKI/8083695 (already has 2500 slices)
# ✅ Skipping KKI/8263351 (already has 2500 slices)
# ✅ Skipping KKI/8337695 (already has 2500 slices)
# ✅ Skipping KKI/8432725 (already has 2500 slices)
# ✅ Skipping KKI/8628223 (already has 2500 slices)
# ✅ Skipping KKI/8658218 (already has 2500 slices)
# ✅ Skipping KKI/9922944 (already has 2500 slices)
# Processing site: NeuroIMAGE
# ✅ Skipping NeuroIMAGE/1017176 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1125505 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1208586 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1312097 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1411495 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1438162 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1538046 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1585708 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/1588809 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2029723 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2074737 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2352986 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2419464 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2574674 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2671604 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2756846 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2876903 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/2961243 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3007585 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3048588 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3082137 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3108222 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3190461 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3304956 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3322144 (already has 2500 slices)
# ✅ Skipping NeuroIMAGE/3449233 (already has 2500 slices)
# Processing: NeuroIMAGE/3515506 with sfnwmrda3515506_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3515506
# Processing: NeuroIMAGE/3566449 with sfnwmrda3566449_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3566449
# Processing: NeuroIMAGE/3808273 with sfnwmrda3808273_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3808273
# Processing: NeuroIMAGE/3858891 with sfnwmrda3858891_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3858891
# Processing: NeuroIMAGE/3888614 with sfnwmrda3888614_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3888614
# Processing: NeuroIMAGE/3941358 with sfnwmrda3941358_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3941358
# Processing: NeuroIMAGE/3959823 with sfnwmrda3959823_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3959823
# Processing: NeuroIMAGE/3980079 with sfnwmrda3980079_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/3980079
# Processing: NeuroIMAGE/4020830 with sfnwmrda4020830_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/4020830
# Processing: NeuroIMAGE/4134561 with sfnwmrda4134561_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/4134561
# Processing: NeuroIMAGE/4239636 with sfnwmrda4239636_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/4239636
# Processing: NeuroIMAGE/4285031 with sfnwmrda4285031_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/4285031
# Processing: NeuroIMAGE/4919979 with sfnwmrda4919979_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/4919979
# Processing: NeuroIMAGE/5045355 with sfnwmrda5045355_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/5045355
# Processing: NeuroIMAGE/6115230 with sfnwmrda6115230_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/6115230
# Processing: NeuroIMAGE/7339173 with sfnwmrda7339173_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/7339173
# Processing: NeuroIMAGE/7446626 with sfnwmrda7446626_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/7446626
# Processing: NeuroIMAGE/7504392 with sfnwmrda7504392_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/7504392
# Processing: NeuroIMAGE/8387093 with sfnwmrda8387093_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/8387093
# Processing: NeuroIMAGE/8409791 with sfnwmrda8409791_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/8409791
# Processing: NeuroIMAGE/8991934 with sfnwmrda8991934_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/8991934
# Processing: NeuroIMAGE/9956994 with sfnwmrda9956994_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NeuroIMAGE/9956994
# Processing site: NYU
# Processing: NYU/1000804 with sfnwmrda1000804_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1000804
# Processing: NYU/1023964 with sfnwmrda1023964_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1023964
# Processing: NYU/1057962 with sfnwmrda1057962_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU/1057962
# Processing: NYU/1099481 with sfnwmrda1099481_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1099481
# Processing: NYU/1127915 with sfnwmrda1127915_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1127915
# Processing: NYU/1187766 with sfnwmrda1187766_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1187766
# Processing: NYU/1208795 with sfnwmrda1208795_session_1_rest_2.nii.gz
# ✅ Created 2500 slices for NYU/1208795
# Processing: NYU/1283494 with sfnwmrda1283494_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for NYU
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10025
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10029
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10017
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10049
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10070
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10071
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10033
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10072
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10073
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10104
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10088
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10040
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10124
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10041
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10125
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10007
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10126
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10127
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10128
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10129
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10013
# ⚠ Subject dir missing: /Volumes/Samsung_PSSD_T7_Shield/Athena PreProccessd/NYU/10043
# Processing site: OHSU
# Processing: OHSU/1084283 with sfnwmrda1084283_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1084283
# Processing: OHSU/1084884 with sfnwmrda1084884_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1084884
# Processing: OHSU/1108916 with sfnwmrda1108916_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1108916
# Processing: OHSU/1206380 with sfnwmrda1206380_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1206380
# Processing: OHSU/1340333 with sfnwmrda1340333_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1340333
# Processing: OHSU/1386056 with sfnwmrda1386056_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1386056
# Processing: OHSU/1411223 with sfnwmrda1411223_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1411223
# Processing: OHSU/1418396 with sfnwmrda1418396_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1418396
# Processing: OHSU/1421489 with sfnwmrda1421489_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1421489
# Processing: OHSU/1481430 with sfnwmrda1481430_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1481430
# Processing: OHSU/1502229 with sfnwmrda1502229_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1502229
# Processing: OHSU/1536593 with sfnwmrda1536593_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1536593
# Processing: OHSU/1548937 with sfnwmrda1548937_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1548937
# Processing: OHSU/1552181 with sfnwmrda1552181_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1552181
# Processing: OHSU/1647968 with sfnwmrda1647968_session_1_rest_1.nii.gz
# ✅ Created 2500 slices for OHSU/1647968
# Processing: OHSU/1664335 with sfnwmrda1664335_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1664335
# Processing: OHSU/1679142 with sfnwmrda1679142_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1679142
# Processing: OHSU/1696588 with sfnwmrda1696588_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1696588
# Processing: OHSU/1743472 with sfnwmrda1743472_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/1743472
# Processing: OHSU/2054310 with sfnwmrda2054310_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2054310
# Processing: OHSU/2054998 with sfnwmrda2054998_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2054998
# Processing: OHSU/2071989 with sfnwmrda2071989_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2071989
# Processing: OHSU/2124248 with sfnwmrda2124248_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2124248
# Processing: OHSU/2155356 with sfnwmrda2155356_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2155356
# Processing: OHSU/2232376 with sfnwmrda2232376_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2232376
# Processing: OHSU/2232413 with sfnwmrda2232413_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2232413
# Processing: OHSU/2288903 with sfnwmrda2288903_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2288903
# Processing: OHSU/2292940 with sfnwmrda2292940_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2292940
# Processing: OHSU/2409220 with sfnwmrda2409220_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2409220
# Processing: OHSU/2415970 with sfnwmrda2415970_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2415970
# Processing: OHSU/2426523 with sfnwmrda2426523_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2426523
# Processing: OHSU/2427434 with sfnwmrda2427434_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2427434
# Processing: OHSU/2455205 with sfnwmrda2455205_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2455205
# Processing: OHSU/2535204 with sfnwmrda2535204_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2535204
# Processing: OHSU/2559559 with sfnwmrda2559559_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2559559
# Processing: OHSU/2561174 with sfnwmrda2561174_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2561174
# Processing: OHSU/2571197 with sfnwmrda2571197_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2571197
# Processing: OHSU/2578455 with sfnwmrda2578455_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2578455
# Processing: OHSU/2620872 with sfnwmrda2620872_session_1_rest_3.nii.gz
# ✅ Created 2500 slices for OHSU/2620872
# Processing: OHSU/2790141 with sfnwmrda2790141_session_1_rest_4.nii.gz
# ✅ Created 2500 slices for OHSU/2790141
# Processing: OHSU/2845989 with sfnwmrda2845989_session_1_rest_3.nii.gz
